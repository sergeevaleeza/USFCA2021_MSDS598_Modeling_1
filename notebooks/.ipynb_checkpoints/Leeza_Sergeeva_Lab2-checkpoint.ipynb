# %% [markdown]
# Leeza Sergeeva
# Lab 2
# 2/14/2022

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import random
from scipy import stats

import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# Use the penguins dataset for the following questions.
#
# 0. Recreate the following set-up which we did in class.
#
# (a) Create the variable is male which is 0 when the penguin is female and 1 when the penguin is male.

# %%
# load penguin dataframe
df_penguins = sns.load_dataset('penguins')

# Create the variable is male which is 0 when the penguin is female and 1 when the penguin is male.
df_penguins['is_male'] = df_penguins['sex'].apply(lambda x : int(x == 'Male'))
df_penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  is_male
# 0       3750.0    Male        1
# 1       3800.0  Female        0
# 2       3250.0  Female        0
# 3          NaN     NaN        0
# 4       3450.0  Female        0

# %% [markdown]
# (b) Find the line of best fit to predict body mass from flipper length and whether the penguin is male or female.

# %%
model = ols(formula = 'body_mass_g ~ flipper_length_mm + is_male', data=df_penguins)
res = model.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            body_mass_g   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.802
# Method:                 Least Squares   F-statistic:                     691.0
# Date:                Mon, 14 Feb 2022   Prob (F-statistic):          2.53e-120
# Time:                        18:33:10   Log-Likelihood:                -2493.9
# No. Observations:                 342   AIC:                             4994.
# Df Residuals:                     339   BIC:                             5005.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
sns.lmplot(x='flipper_length_mm',y='body_mass_g',data=df_penguins, hue='sex')

# %% [markdown]
# 1. Create a scatter plot with flipper length on the x-axis and body mass on the y-axis. Color the points according to the penguin’s sex.

# %%
sns.scatterplot(x='flipper_length_mm',y='body_mass_g',data=df_penguins, hue='sex')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %% [markdown]
# 2. Find the line of best fit for the penguins dataset to predict body mass from flipper length. Plot this on the plot from Q1.

# %%
sns.lmplot(x='flipper_length_mm',y='body_mass_g',data=df_penguins)

# %% [markdown]
# 3. Find two lines of best fit: one for the male and one for the female penguins. Plot this on the plot from Q1.

# %%
p = sns.lmplot(x='flipper_length_mm',y='body_mass_g',data=df_penguins, hue='sex',
          line_kws={'label':"Linear Reg"}, legend=True)

ax = p.axes[0, 0]
ax.legend()
leg = ax.get_legend()
L_labels = leg.get_texts()
# assuming you computed r_squared which is the coefficient of determination somewhere else
slope, intercept, r_value, p_value, std_err = stats.linregress(df_penguins['flipper_length_mm'],df_penguins['body_mass_g'])
label_line_1 = r'$y={0:.1f}x+{1:.1f}'.format(slope,intercept)
label_line_2 = r'$R^2:{0:.2f}$'.format(0.21) # as an exampple or whatever you want[!
L_labels[0].set_text(label_line_1)
L_labels[1].set_text(label_line_2)

# %% [markdown]
# NOTE: For some reason stats.linregress function didn't work and I couldn't get the values for the equation.

# %% [markdown]
# 4. Take the line of best fit from above which used both flipper length and is male. Plot this line with Xis male = 0 and with Xis male = 1. What do you notice?

# %% [markdown]
# If penguin is male then the best fitting line moves up by some value, but the slope stays the same
#
# * y = b0 + b1*x + b2*0 -> y = b0 + b1*x
# * y = b0 + b1*x + b2*1 -> y = b0 + b2 + b1*x

# %%
sns.lmplot(x='flipper_length_mm',y='body_mass_g',data=df_penguins, hue='is_male')
